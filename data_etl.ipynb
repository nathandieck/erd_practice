# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
# Import EDU file
csv_file = "C:/Users/admin/HW/project2/Resources/edu.csv"
edu_df = pd.read_csv(csv_file)
edu_df.head()
# Out:
#       country c_codes  cal_year          GNP   Population  Edu_prime  \
# 0  ARAB WORLD     NaN      2017  16997.50354  414491886.0        NaN
# 1  ARAB WORLD     NaN      2016  16794.06495  406452690.0  83.911949
# 2  ARAB WORLD     NaN      2015  16366.59640  398304960.0  84.720306
# 3  ARAB WORLD     NaN      2014  15895.25148  390043028.0  85.314812
# 4  ARAB WORLD     NaN      2013  15453.22069  381702086.0  84.703484
#
#    Edu_second  Edu_post_second  Edu_lower_second  Unemp
# 0         NaN              NaN               NaN    NaN
# 1         NaN              NaN               NaN    NaN
# 2         NaN              NaN               NaN    NaN
# 3         NaN              NaN               NaN    NaN
# 4         NaN              NaN               NaN    NaN

# %%
# Filter years for 2005, 2010 & 2015

# Indicate reference years
years = (2005, 2010, 2015)

# Filter reference years
edu_df = edu_df[edu_df['cal_year'].isin(years)]

# Select columns
edu_df = edu_df[['country', 'c_codes', 'cal_year', 'GNP', 'Population', 'Edu_prime']]

edu_df
# Out:
#                       country c_codes  cal_year          GNP   Population  \
# 2                  ARAB WORLD     NaN      2015  16366.59640  398304960.0
# 7                  ARAB WORLD     NaN      2010  13942.73328  356508908.0
# 12                 ARAB WORLD     NaN      2005  11537.59540  316264728.0
# 60     CARIBBEAN SMALL STATES     NaN      2015  15516.02300    7204948.0
# 65     CARIBBEAN SMALL STATES     NaN      2010  13380.00937    6984096.0
# ...                       ...     ...       ...          ...          ...
# 15203                  ZAMBIA     ZMB      2010   3000.00000   13850033.0
# 15208                  ZAMBIA     ZMB      2005   2040.00000   12052156.0
# 15256                ZIMBABWE     ZWE      2015   1790.00000   15777451.0
# 15261                ZIMBABWE     ZWE      2010   1240.00000   14086317.0
# 15266                ZIMBABWE     ZWE      2005   1410.00000   12940032.0
#
#        Edu_prime
# 2      84.720306
# 7      85.171822
# 12     82.122704
# 60           NaN
# 65     91.299530
# ...          ...
# 15203  95.396584
# 15208  80.275414
# 15256        NaN
# 15261        NaN
# 15266        NaN
#
# [792 rows x 6 columns]

# %%
# import HDI File
csv_file = "C:/Users/admin/HW/project2/Resources/human_development_index.csv"
hdi_df = pd.read_csv(csv_file)
hdi_df.head()
# Out:
#        Country HDI_Rank_2018   1990   1991   1992   1993   1994   1995   1996  \
# 0  Afghanistan           170  0.298  0.304  0.312  0.308  0.303  0.327  0.331
# 1      Albania            69  0.644  0.625  0.608  0.611  0.617  0.629  0.639
# 2      Algeria            82  0.578  0.582  0.589  0.593  0.597  0.602  0.610
# 3      Andorra            36    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4       Angola           149    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1997  ...   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  0.335  ...  0.447  0.464  0.465  0.479  0.485  0.488  0.490  0.491  0.493
# 1  0.639  ...  0.729  0.740  0.759  0.771  0.781  0.787  0.788  0.788  0.789
# 2  0.619  ...  0.720  0.730  0.738  0.737  0.746  0.749  0.751  0.755  0.758
# 3    NaN  ...  0.830  0.828  0.827  0.849  0.846  0.853  0.850  0.854  0.852
# 4    NaN  ...  0.508  0.510  0.525  0.537  0.547  0.557  0.565  0.570  0.576
#
#     2018
# 0  0.496
# 1  0.791
# 2  0.759
# 3  0.857
# 4  0.574
#
# [5 rows x 31 columns]

# %%
# Transpose HDI DataFrame

hdi_df = hdi_df.melt(id_vars=['Country', 'HDI_Rank_2018'],
                     var_name =['cal_year'],
                     value_name ='HDI')

hdi_df
# Out:
#                                                 Country HDI_Rank_2018  \
# 0                                           Afghanistan           170
# 1                                               Albania            69
# 2                                               Algeria            82
# 3                                               Andorra            36
# 4                                                Angola           149
# ...                                                 ...           ...
# 6143                                 Sub-Saharan Africa
# 6144                          Least Developed Countries
# 6145                     Small Island Developing States
# 6146  Organization for Economic Co-operation and Dev...
# 6147                                              World
#
#      cal_year    HDI
# 0        1990  0.298
# 1        1990  0.644
# 2        1990  0.578
# 3        1990    NaN
# 4        1990    NaN
# ...       ...    ...
# 6143     2018  0.541
# 6144     2018  0.528
# 6145     2018  0.723
# 6146     2018  0.895
# 6147     2018  0.731
#
# [6148 rows x 4 columns]

# %%
# # Filter reference years
# hdi_df = hdi_df[hdi_df['cal_year'].isin(years)]

# hdi_df

# %%
# Connect to local Database
USERNAME = "postgres"
PASSWORD = "postgres"
DATABASE = "Project_2"
rds_connection_string = f"{USERNAME}:{PASSWORD}@localhost:5432/{DATABASE}"
print(rds_connection_string)
engine = create_engine(f'postgresql://{rds_connection_string}')
# Out:
# postgres:postgres@localhost:5432/Project_2

# %%
# Check for tables
engine.table_names()
# Out:
# ['edu', 'hdi']

# %%
# check for column names
pd.read_sql_query('select * from hdi', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [country, hdi_rank_2018, cal_year, hdi]
# Index: []

# %%
# check for column names
pd.read_sql_query('select * from edu', con=engine).head()
# Out:
# Empty DataFrame
# Columns: [country, c_codes, cal_year, gnp, population, edu_prime]
# Index: []

# %%
# Use pandas to load csv converted DataFrame into database
edu_df.to_sql(name='edu', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "GNP" of relation "edu" does not exist
# LINE 1: INSERT INTO edu (country, c_codes, cal_year, "GNP", "Populat...
#                                                      ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-10-9a259f26bebf> in <module>
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 edu_df.to_sql(name='edu', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "GNP" of relation "edu" does not exist
# LINE 1: INSERT INTO edu (country, c_codes, cal_year, "GNP", "Populat...
#                                                      ^
#
# [SQL: INSERT INTO edu (country, c_codes, cal_year, "GNP", "Population", "Edu_prime") VALUES (%(country)s, %(c_codes)s, %(cal_year)s, %(GNP)s, %(Population)s, %(Edu_prime)s)]
# [parameters: ({'country': 'ARAB WORLD', 'c_codes': None, 'cal_year': 2015, 'GNP': 16366.5964, 'Population': 398304960.0, 'Edu_prime': 84.7203064}, {'country': 'ARAB WORLD', 'c_codes': None, 'cal_year': 2010, 'GNP': 13942.73328, 'Population': 356508908.0, 'Edu_prime': 85.17182159}, {'country': 'ARAB WORLD', 'c_codes': None, 'cal_year': 2005, 'GNP': 11537.5954, 'Population': 316264728.0, 'Edu_prime': 82.12270355}, {'country': 'CARIBBEAN SMALL STATES', 'c_codes': None, 'cal_year': 2015, 'GNP': 15516.023000000001, 'Population': 7204948.0, 'Edu_prime': None}, {'country': 'CARIBBEAN SMALL STATES', 'c_codes': None, 'cal_year': 2010, 'GNP': 13380.00937, 'Population': 6984096.0, 'Edu_prime': 91.29953003}, {'country': 'CARIBBEAN SMALL STATES', 'c_codes': None, 'cal_year': 2005, 'GNP': 11182.94029, 'Population': 6761932.0, 'Edu_prime': 89.85991669}, {'country': 'CENTRAL EUROPE AND THE BALTICS', 'c_codes': None, 'cal_year': 2015, 'GNP': 24919.1779, 'Population': 103257751.0, 'Edu_prime': 97.05641937}, {'country': 'CENTRAL EUROPE AND THE BALTICS', 'c_codes': None, 'cal_year': 2010, 'GNP': 20007.60054, 'Population': 104543801.0, 'Edu_prime': 96.92649078}  ... displaying 10 of 792 total bound parameter sets ...  {'country': 'ZIMBABWE', 'c_codes': 'ZWE', 'cal_year': 2010, 'GNP': 1240.0, 'Population': 14086317.0, 'Edu_prime': None}, {'country': 'ZIMBABWE', 'c_codes': 'ZWE', 'cal_year': 2005, 'GNP': 1410.0, 'Population': 12940032.0, 'Edu_prime': None})]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# Use pandas to load csv converted DataFrame into database
hdi_df.to_sql(name='hdi', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# UndefinedColumn: column "Country" of relation "hdi" does not exist
# LINE 1: INSERT INTO hdi ("Country", "HDI_Rank_2018", cal_year, "HDI"...
#                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-05af6c4903c9> in <module>
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 hdi_df.to_sql(name='hdi', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Country" of relation "hdi" does not exist
# LINE 1: INSERT INTO hdi ("Country", "HDI_Rank_2018", cal_year, "HDI"...
#                          ^
#
# [SQL: INSERT INTO hdi ("Country", "HDI_Rank_2018", cal_year, "HDI") VALUES (%(Country)s, %(HDI_Rank_2018)s, %(cal_year)s, %(HDI)s)]
# [parameters: ({'Country': 'Afghanistan', 'HDI_Rank_2018': '170', 'cal_year': '1990', 'HDI': 0.298}, {'Country': 'Albania', 'HDI_Rank_2018': '69', 'cal_year': '1990', 'HDI': 0.644}, {'Country': 'Algeria', 'HDI_Rank_2018': '82', 'cal_year': '1990', 'HDI': 0.578}, {'Country': 'Andorra', 'HDI_Rank_2018': '36', 'cal_year': '1990', 'HDI': None}, {'Country': 'Angola', 'HDI_Rank_2018': '149', 'cal_year': '1990', 'HDI': None}, {'Country': 'Antigua and Barbuda', 'HDI_Rank_2018': '74', 'cal_year': '1990', 'HDI': None}, {'Country': 'Argentina', 'HDI_Rank_2018': '48', 'cal_year': '1990', 'HDI': 0.7070000000000001}, {'Country': 'Armenia', 'HDI_Rank_2018': '81', 'cal_year': '1990', 'HDI': 0.633}  ... displaying 10 of 6148 total bound parameter sets ...  {'Country': 'Organization for Economic Co-operation and Development', 'HDI_Rank_2018': ' ', 'cal_year': '2018', 'HDI': 0.895}, {'Country': 'World', 'HDI_Rank_2018': ' ', 'cal_year': '2018', 'HDI': 0.731})]
# (Background on this error at: http://sqlalche.me/e/f405)
