# %% [markdown]
# # Part 1
# * Import dependencies
# * Define source data, including
#     * Resources/human_development_index.csv, a list of HDI scores for the world's countries put out by the UN
#     * Resources/edu.csv, a list of education indicators put out by the World Bank and downloaded from Kaggle
#     * Resources/countries_geo.csv, a list of countries by geographic coordinates
#     * Resources/continent.csv, a list of countries by continent

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import numpy as np

#pycountry is a library that we'll use to standardize the names of the countries in our miscellaneous datasets. 
#It must be pip-instealled (pip install pycountry) before you can use it. 
import pycountry

# %%
#HDI Spreadsheet
csv_hdi = "Resources/human_development_index.csv"

#EDU Spreadsheet
csv_edu = "Resources/edu.csv"

#Geographic Coordinates
csv_geo = "Resources/countries_geo.csv"

#Continents
csv_con = "Resources/continent.csv"

# %% [markdown]
# # Part 2
# * Process geographic coordinate and country files
# * Standardize country names within this two sheets and merge them as df_geo
# * Set the standardized country name as the index
# * Verify

# %%
#load the "csv_geo" file
geo_df = pd.read_csv(csv_geo)
geo_df.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
#drop the current country column that is not valuable
geo_drop = geo_df.drop(columns=['country'])
geo_drop.head()
# Out:
#     latitude  longitude                  name
# 0  42.546245   1.601554               Andorra
# 1  23.424076  53.847818  United Arab Emirates
# 2  33.939110  67.709953           Afghanistan
# 3  17.060816 -61.796428   Antigua and Barbuda
# 4  18.220554 -63.068615              Anguilla

# %%
#change "name" to "country" to prepare for the matching ID
geo_renamed = geo_drop.rename(columns={"name": "country"})
geo_renamed.head()
# Out:
#     latitude  longitude               country
# 0  42.546245   1.601554               Andorra
# 1  23.424076  53.847818  United Arab Emirates
# 2  33.939110  67.709953           Afghanistan
# 3  17.060816 -61.796428   Antigua and Barbuda
# 4  18.220554 -63.068615              Anguilla

# %%
#Load the csv_con file

con_df = pd.read_csv(csv_con)
con_df.head()
# Out:
#           country code country-code sub-region intermediate-region region-code
# 0     Afghanistan   AF          AFG       Asia       Southern Asia         NaN
# 1   Aland Islands   AX          ALA     Europe     Northern Europe         NaN
# 2         Albania   AL          ALB     Europe     Southern Europe         NaN
# 3         Algeria   DZ          DZA     Africa     Northern Africa         NaN
# 4  American Samoa   AS          ASM    Oceania           Polynesia         NaN

# %%
#change "name" to "country" to prepare for the matching ID
con_renamed = con_df.rename(columns={"name": "country"})
con_renamed.head()
# Out:
#           country code country-code sub-region intermediate-region region-code
# 0     Afghanistan   AF          AFG       Asia       Southern Asia         NaN
# 1   Aland Islands   AX          ALA     Europe     Northern Europe         NaN
# 2         Albania   AL          ALB     Europe     Southern Europe         NaN
# 3         Algeria   DZ          DZA     Africa     Northern Africa         NaN
# 4  American Samoa   AS          ASM    Oceania           Polynesia         NaN

# %%
#merge location detail files based on country
df_geo = pd.merge(geo_renamed,
                  con_renamed,
                  on='country')
df_geo.head()
# Out:
#     latitude  longitude               country code country-code sub-region  \
# 0  42.546245   1.601554               Andorra   AD          AND     Europe
# 1  23.424076  53.847818  United Arab Emirates   AE          ARE       Asia
# 2  33.939110  67.709953           Afghanistan   AF          AFG       Asia
# 3  17.060816 -61.796428   Antigua and Barbuda   AG          ATG   Americas
# 4  18.220554 -63.068615              Anguilla   AI          AIA   Americas
#
#                intermediate-region region-code
# 0                  Southern Europe         NaN
# 1                     Western Asia         NaN
# 2                    Southern Asia         NaN
# 3  Latin America and the Caribbean   Caribbean
# 4  Latin America and the Caribbean   Caribbean

# %%
#rearrange the order of columns
df_geo = df_geo[['country', 'latitude', 'longitude', 'code','country-code','sub-region','intermediate-region']]
df_geo.head()
# Out:
#                 country   latitude  longitude code country-code sub-region  \
# 0               Andorra  42.546245   1.601554   AD          AND     Europe
# 1  United Arab Emirates  23.424076  53.847818   AE          ARE       Asia
# 2           Afghanistan  33.939110  67.709953   AF          AFG       Asia
# 3   Antigua and Barbuda  17.060816 -61.796428   AG          ATG   Americas
# 4              Anguilla  18.220554 -63.068615   AI          AIA   Americas
#
#                intermediate-region
# 0                  Southern Europe
# 1                     Western Asia
# 2                    Southern Asia
# 3  Latin America and the Caribbean
# 4  Latin America and the Caribbean

# %%
#this is the code that will assign a standardized country name to each country in the list.
#it takes a second to run

country_std = []

for country in df_geo.country:
    try:
        result = pycountry.countries.search_fuzzy(country)
    except LookupError:
        result = 0
    if result != 0:
        string = str(result[0])
        string2 = string.split("'")
        final = string2[5]
    else:
        final = np.nan
    
    country_std.append(final)

df_geo['country_std'] = country_std

df_geo.head()
# Out:
#                 country   latitude  longitude code country-code sub-region  \
# 0               Andorra  42.546245   1.601554   AD          AND     Europe
# 1  United Arab Emirates  23.424076  53.847818   AE          ARE       Asia
# 2           Afghanistan  33.939110  67.709953   AF          AFG       Asia
# 3   Antigua and Barbuda  17.060816 -61.796428   AG          ATG   Americas
# 4              Anguilla  18.220554 -63.068615   AI          AIA   Americas
#
#                intermediate-region           country_std
# 0                  Southern Europe               Andorra
# 1                     Western Asia  United Arab Emirates
# 2                    Southern Asia           Afghanistan
# 3  Latin America and the Caribbean   Antigua and Barbuda
# 4  Latin America and the Caribbean              Anguilla

# %%
#fixing some faults in the Pycountry program that I can't fix automatically so I'm doing it by hand.
#Specifically PyCountry thinks that Niger is part of Nigeria (and is wrong)
#And while it normally lists island protectorates and overseas territories separately (e.g. Guernsey is Guernesy),
#For some of the French overseas protectorates they list them as part of France.
#These errors mean I can't use the standard country name as a Primary Key later so I'm fixing them. 

for index, row in df_geo.iterrows():
    if row[0] == "Niger":
        print("Niger")
        df_geo.loc[index, 'country_std'] = "Niger"
    elif row[0] == "Guadeloupe":
        print("Guadeloupe")
        df_geo.loc[index, 'country_std'] = "Guadeloupe"
    elif row[0] == "Mayotte":
        df_geo.loc[index, 'country_std'] = "Mayotte"
        print("Mayotte")
# Out:
# Guadeloupe
# Niger
# Mayotte

# %% [markdown]
# ### The next cell contains what should be the final Geographic dataframe for the purpose of configuring the SQL table.

# %%
df_geo = df_geo.set_index("country_std")

#Discovered the hard way that SQL doesn't care for hyphens much so I'm replacing the hyphens with underscores.
df_geo.columns = ['country', 'latitude', 'longitude', 'code', 'country_code', 'sub_region', 'intermediate_region']

df_geo.head()
# Out:
#                                    country   latitude  longitude code  \
# country_std
# Andorra                            Andorra  42.546245   1.601554   AD
# United Arab Emirates  United Arab Emirates  23.424076  53.847818   AE
# Afghanistan                    Afghanistan  33.939110  67.709953   AF
# Antigua and Barbuda    Antigua and Barbuda  17.060816 -61.796428   AG
# Anguilla                          Anguilla  18.220554 -63.068615   AI
#
#                      country_code sub_region              intermediate_region
# country_std
# Andorra                       AND     Europe                  Southern Europe
# United Arab Emirates          ARE       Asia                     Western Asia
# Afghanistan                   AFG       Asia                    Southern Asia
# Antigua and Barbuda           ATG   Americas  Latin America and the Caribbean
# Anguilla                      AIA   Americas  Latin America and the Caribbean

# %% [markdown]
# # Part 3
# * Process HDI files as df_hdi
# * Standardize country names within this two sheets and merge them
# * Set the standardized country name as the index
# * Verify

# %%
#import

df_hdi = pd.read_csv(csv_hdi)

df_hdi.head()
# Out:
#        country  hdi_rank_2018   1990   1991   1992   1993   1994   1995  \
# 0  Afghanistan          170.0  0.298  0.304  0.312  0.308  0.303  0.327
# 1      Albania           69.0  0.644  0.625  0.608  0.611  0.617  0.629
# 2      Algeria           82.0  0.578  0.582  0.589  0.593  0.597  0.602
# 3      Andorra           36.0    NaN    NaN    NaN    NaN    NaN    NaN
# 4       Angola          149.0    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1996   1997  ...   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0  0.331  0.335  ...  0.447  0.464  0.465  0.479  0.485  0.488  0.490  0.491
# 1  0.639  0.639  ...  0.729  0.740  0.759  0.771  0.781  0.787  0.788  0.788
# 2  0.610  0.619  ...  0.720  0.730  0.738  0.737  0.746  0.749  0.751  0.755
# 3    NaN    NaN  ...  0.830  0.828  0.827  0.849  0.846  0.853  0.850  0.854
# 4    NaN    NaN  ...  0.508  0.510  0.525  0.537  0.547  0.557  0.565  0.570
#
#     2017   2018
# 0  0.493  0.496
# 1  0.789  0.791
# 2  0.758  0.759
# 3  0.852  0.857
# 4  0.576  0.574
#
# [5 rows x 31 columns]

# %%
df_hdi = df_hdi[["country", "hdi_rank_2018", "2018", "2015", "2010", "2005"]]

df_hdi.head()
# Out:
#        country  hdi_rank_2018   2018   2015   2010   2005
# 0  Afghanistan          170.0  0.496  0.490  0.464  0.410
# 1      Albania           69.0  0.791  0.788  0.740  0.702
# 2      Algeria           82.0  0.759  0.751  0.730  0.694
# 3      Andorra           36.0  0.857  0.850  0.828  0.819
# 4       Angola          149.0  0.574  0.565  0.510  0.453

# %%
#Alright, so the UN names ("Venezuela (Bolivarian Republic of)") are causing Pycountry to choke because it doesn't like the perentheses. 
#This is my crack at solving it without resorting to doing it by hand

df_hdi = df_hdi.replace(to_replace=" \(", value=", ", regex=True)
df_hdi = df_hdi.replace(to_replace="\)", value="", regex=True)

#this significantly improves though does not perfect output.

# %%
#careful, this cell takes a fair amount of time to run.
#this is the code that will assign a standardized country name to each country in the list.

country_std = []

for country in df_hdi.country:
    try:
        result = pycountry.countries.search_fuzzy(country)
    except LookupError:
        result = 0
    if result != 0:
        string = str(result[0])
        string2 = string.split("'")
        final = string2[5]
    else:
        final = np.nan
    
    country_std.append(final)

df_hdi['country_std'] = country_std

df_hdi.head()
# Out:
#        country  hdi_rank_2018   2018   2015   2010   2005  country_std
# 0  Afghanistan          170.0  0.496  0.490  0.464  0.410  Afghanistan
# 1      Albania           69.0  0.791  0.788  0.740  0.702      Albania
# 2      Algeria           82.0  0.759  0.751  0.730  0.694      Algeria
# 3      Andorra           36.0  0.857  0.850  0.828  0.819      Andorra
# 4       Angola          149.0  0.574  0.565  0.510  0.453       Angola

# %%
#fixing some faults in the Pycountry program that I can't fix automatically so I'm doing it by hand.
#Specifically PyCountry thinks that Niger is part of Nigeria (and is wrong)
#And while it normally lists island protectorates and overseas territories separately (e.g. Guernsey is Guernesy),
#For some of the French overseas protectorates they list them as part of France.
#These errors mean I can't use the standard country name as a Primary Key later so I'm fixing them. 

for index, row in df_hdi.iterrows():
    if row[0] == "Niger":
        print("Niger")
        df_hdi.loc[index, 'country_std'] = "Niger"
    elif row[0] == "Guadeloupe":
        print("Guadeloupe")
        df_hdi.loc[index, 'country_std'] = "Guadeloupe"
    elif row[0] == "Mayotte":
        df_hdi.loc[index, 'country_std'] = "Mayotte"
        print("Mayotte")
# Out:
# Niger

# %% [markdown]
# ### The next cell contains what should be the final HDI dataframe for the purpose of configuring the SQL table.

# %%
#because I'm using "country_std" as a primary key, we must sadly eliminate those countries that still don't have one (e.g. D.R. Congo for some reason)
df_hdi = df_hdi.dropna(axis=0, subset=['country_std'])

df_hdi = df_hdi.set_index("country_std", drop=True)

#can't name columns with a number in SQL, apparently,s o I've replaced them here.
df_hdi.columns = ['country', 'hdi_rank_2018', 'hdi_2018', 'hdi_2015', 'hdi_2010', 'hdi_2005']

df_hdi.head()
# Out:
#                  country  hdi_rank_2018  hdi_2018  hdi_2015  hdi_2010  \
# country_std
# Afghanistan  Afghanistan          170.0     0.496     0.490     0.464
# Albania          Albania           69.0     0.791     0.788     0.740
# Algeria          Algeria           82.0     0.759     0.751     0.730
# Andorra          Andorra           36.0     0.857     0.850     0.828
# Angola            Angola          149.0     0.574     0.565     0.510
#
#              hdi_2005
# country_std
# Afghanistan     0.410
# Albania         0.702
# Algeria         0.694
# Andorra         0.819
# Angola          0.453

# %% [markdown]
# # Part 4
# * Process EDU files as df_edu
# * Transpose them so we can use the country name as the primary key like for the other dfs
# * Generate a standardized country name and set it as the index
# * Verify

# %%
df_edu = pd.read_csv(csv_edu)

df_edu.head()
# Out:
#       country c_codes  cal_year          gnp   population  edu_prime  \
# 0  ARAB WORLD     NaN      2017  16997.50354  414491886.0        NaN
# 1  ARAB WORLD     NaN      2016  16794.06495  406452690.0  83.911949
# 2  ARAB WORLD     NaN      2015  16366.59640  398304960.0  84.720306
# 3  ARAB WORLD     NaN      2014  15895.25148  390043028.0  85.314812
# 4  ARAB WORLD     NaN      2013  15453.22069  381702086.0  84.703484
#
#    edu_second  edu_post_second  edu_lower_second  unemp
# 0         NaN              NaN               NaN    NaN
# 1         NaN              NaN               NaN    NaN
# 2         NaN              NaN               NaN    NaN
# 3         NaN              NaN               NaN    NaN
# 4         NaN              NaN               NaN    NaN

# %%
# Filter years for 2005, 2010 & 2015

# Indicate reference years
years = (2005, 2010, 2015)

# Filter reference years
df_edu = df_edu[df_edu['cal_year'].isin(years)]

# Select columns
df_edu = df_edu[['country','cal_year', 'gnp', 'population', 'edu_prime']]

df_edu.head()
# Out:
#                    country  cal_year          gnp   population  edu_prime
# 2               ARAB WORLD      2015  16366.59640  398304960.0  84.720306
# 7               ARAB WORLD      2010  13942.73328  356508908.0  85.171822
# 12              ARAB WORLD      2005  11537.59540  316264728.0  82.122704
# 60  CARIBBEAN SMALL STATES      2015  15516.02300    7204948.0        NaN
# 65  CARIBBEAN SMALL STATES      2010  13380.00937    6984096.0  91.299530

# %%
#disaggregating the dataframes by years so that we can use the country name as the primary key later.

#2005
df_edu2005 = pd.DataFrame(columns = df_edu.columns)

cond2005 = df_edu["cal_year"] == 2005
rows2005 = df_edu.loc[cond2005, :]
df_edu2005 = df_edu2005.append(rows2005, ignore_index=True)

#2010

df_edu2010 = pd.DataFrame(columns = df_edu.columns)

cond2010 = df_edu["cal_year"] == 2010
rows2010 = df_edu.loc[cond2010, :]
df_edu2010 = df_edu2010.append(rows2010, ignore_index=True)

#2015

df_edu2015 = pd.DataFrame(columns = df_edu.columns)

cond2015 = df_edu["cal_year"] == 2015
rows2015 = df_edu.loc[cond2015, :]
df_edu2015 = df_edu2015.append(rows2015, ignore_index=True)

# %%
df_edu_combined = df_edu2005.merge(df_edu2010, how='inner', on='country', suffixes = ("_2005", "_2010"))

df_edu_combined.head()
# Out:
#                           country cal_year_2005      gnp_2005  \
# 0                      ARAB WORLD          2005  11537.595400
# 1          CARIBBEAN SMALL STATES          2005  11182.940290
# 2  CENTRAL EUROPE AND THE BALTICS          2005  13901.893660
# 3      EARLY-DEMOGRAPHIC DIVIDEND          2005   5098.028384
# 4             EAST ASIA & PACIFIC          2005   8010.371761
#
#    population_2005  edu_prime_2005 cal_year_2010      gnp_2010  \
# 0     3.162647e+08       82.122704          2010  13942.733280
# 1     6.761932e+06       89.859917          2010  13380.009370
# 2     1.061738e+08       96.948441          2010  20007.600540
# 3     2.691528e+09       84.594681          2010   6859.388641
# 4     2.131363e+09       91.439407          2010  11732.345760
#
#    population_2010  edu_prime_2010
# 0     3.565089e+08       85.171822
# 1     6.984096e+06       91.299530
# 2     1.045438e+08       96.926491
# 3     2.909411e+09       89.960541
# 4     2.207155e+09      102.004013

# %%
df_edu_final = df_edu_combined.merge(df_edu2015, how='inner', on='country')

df_edu_final.head()
# Out:
#                           country cal_year_2005      gnp_2005  \
# 0                      ARAB WORLD          2005  11537.595400
# 1          CARIBBEAN SMALL STATES          2005  11182.940290
# 2  CENTRAL EUROPE AND THE BALTICS          2005  13901.893660
# 3      EARLY-DEMOGRAPHIC DIVIDEND          2005   5098.028384
# 4             EAST ASIA & PACIFIC          2005   8010.371761
#
#    population_2005  edu_prime_2005 cal_year_2010      gnp_2010  \
# 0     3.162647e+08       82.122704          2010  13942.733280
# 1     6.761932e+06       89.859917          2010  13380.009370
# 2     1.061738e+08       96.948441          2010  20007.600540
# 3     2.691528e+09       84.594681          2010   6859.388641
# 4     2.131363e+09       91.439407          2010  11732.345760
#
#    population_2010  edu_prime_2010 cal_year           gnp    population  \
# 0     3.565089e+08       85.171822     2015  16366.596400  3.983050e+08
# 1     6.984096e+06       91.299530     2015  15516.023000  7.204948e+06
# 2     1.045438e+08       96.926491     2015  24919.177900  1.032578e+08
# 3     2.909411e+09       89.960541     2015   8725.901971  3.127579e+09
# 4     2.207155e+09      102.004013     2015  16135.571170  2.283108e+09
#
#    edu_prime
# 0  84.720306
# 1        NaN
# 2  97.056419
# 3  93.682671
# 4  93.585663

# %%
df_edu_final = df_edu_final.rename(columns={"cal_year": "cal_year_2015", "gnp": "gnp_2015", "population": "population_2015", "edu_prime": "edu_prime_2015"})

# %%
df_edu_final = df_edu_final.drop(['cal_year_2005', 'cal_year_2010', 'cal_year_2015'], axis=1)

df_edu_final.head()
# Out:
#                           country      gnp_2005  population_2005  \
# 0                      ARAB WORLD  11537.595400     3.162647e+08
# 1          CARIBBEAN SMALL STATES  11182.940290     6.761932e+06
# 2  CENTRAL EUROPE AND THE BALTICS  13901.893660     1.061738e+08
# 3      EARLY-DEMOGRAPHIC DIVIDEND   5098.028384     2.691528e+09
# 4             EAST ASIA & PACIFIC   8010.371761     2.131363e+09
#
#    edu_prime_2005      gnp_2010  population_2010  edu_prime_2010  \
# 0       82.122704  13942.733280     3.565089e+08       85.171822
# 1       89.859917  13380.009370     6.984096e+06       91.299530
# 2       96.948441  20007.600540     1.045438e+08       96.926491
# 3       84.594681   6859.388641     2.909411e+09       89.960541
# 4       91.439407  11732.345760     2.207155e+09      102.004013
#
#        gnp_2015  population_2015  edu_prime_2015
# 0  16366.596400     3.983050e+08       84.720306
# 1  15516.023000     7.204948e+06             NaN
# 2  24919.177900     1.032578e+08       97.056419
# 3   8725.901971     3.127579e+09       93.682671
# 4  16135.571170     2.283108e+09       93.585663

# %%
#careful, this cell takes a fair amount of time to run.
df_edu = df_edu_final

#this is the code that will assign a standardized country name to each country in the list.

country_std = []

for country in df_edu.country:
    try:
        result = pycountry.countries.search_fuzzy(country)
    except LookupError:
        result = 0
    if result != 0:
        string = str(result[0])
        string2 = string.split("'")
        final = string2[5]
    else:
        final = np.nan
    
    country_std.append(final)

df_edu['country_std'] = country_std

df_edu.head()
# Out:
#                           country      gnp_2005  population_2005  \
# 0                      ARAB WORLD  11537.595400     3.162647e+08
# 1          CARIBBEAN SMALL STATES  11182.940290     6.761932e+06
# 2  CENTRAL EUROPE AND THE BALTICS  13901.893660     1.061738e+08
# 3      EARLY-DEMOGRAPHIC DIVIDEND   5098.028384     2.691528e+09
# 4             EAST ASIA & PACIFIC   8010.371761     2.131363e+09
#
#    edu_prime_2005      gnp_2010  population_2010  edu_prime_2010  \
# 0       82.122704  13942.733280     3.565089e+08       85.171822
# 1       89.859917  13380.009370     6.984096e+06       91.299530
# 2       96.948441  20007.600540     1.045438e+08       96.926491
# 3       84.594681   6859.388641     2.909411e+09       89.960541
# 4       91.439407  11732.345760     2.207155e+09      102.004013
#
#        gnp_2015  population_2015  edu_prime_2015 country_std
# 0  16366.596400     3.983050e+08       84.720306         NaN
# 1  15516.023000     7.204948e+06             NaN         NaN
# 2  24919.177900     1.032578e+08       97.056419         NaN
# 3   8725.901971     3.127579e+09       93.682671         NaN
# 4  16135.571170     2.283108e+09       93.585663         NaN

# %%
#fixing some faults in the Pycountry program that I can't fix automatically so I'm doing it by hand.
#Specifically PyCountry thinks that Niger is part of Nigeria (and is wrong)
#And while it normally lists island protectorates and overseas territories separately (e.g. Guernsey is Guernesy),
#For some of the French overseas protectorates they list them as part of France.
#These errors mean I can't use the standard country name as a Primary Key later so I'm fixing them. 

for index, row in df_edu.iterrows():
    if row[0] == ("NIGER"):
        print("Niger")
        df_edu.loc[index, 'country_std'] = "Niger"
    elif row[0] == "GUADELOUPE":
        print("Guadeloupe")
        df_edu.loc[index, 'country_std'] = "Guadeloupe"
    elif row[0] == "MAYOTTE":
        df_edu.loc[index, 'country_std'] = "Mayotte"
        print("Mayotte")
    elif row[0] == "CURACAO":
        df_edu.loc[index, 'country_std'] = "Curacao"
        print("Curacao")
    elif row[0] == "KOSOVO":
        df_edu.loc[index, 'country_std'] = "Kosovo"
        print("Kosovo")
# Out:
# Curacao
# Kosovo
# Niger

# %%
#drop the null rows

df_edu = df_edu.dropna(axis=0, subset=['country_std'])

df_edu.head()
# Out:
#            country  gnp_2005  population_2005  edu_prime_2005  gnp_2010  \
# 47     AFGHANISTAN    1010.0       25070798.0             NaN    1590.0
# 48         ALBANIA    6060.0        3011487.0             NaN    9540.0
# 49         ALGERIA   10430.0       33288437.0       93.185028   12580.0
# 50  AMERICAN SAMOA       NaN          59118.0             NaN       NaN
# 51         ANDORRA       NaN          78867.0             NaN       NaN
#
#     population_2010  edu_prime_2010  gnp_2015  population_2015  \
# 47       28803167.0             NaN    1940.0       33736494.0
# 48        2913021.0       89.237343   11470.0        2880703.0
# 49       36117637.0       95.538918   14220.0       39871528.0
# 50          55637.0             NaN       NaN          55537.0
# 51          84449.0             NaN       NaN          78014.0
#
#     edu_prime_2015     country_std
# 47             NaN     Afghanistan
# 48      104.468193         Albania
# 49      105.436417         Algeria
# 50             NaN  American Samoa
# 51             NaN         Andorra

# %%
len(df_edu)
# Out:
# 195

# %% [markdown]
# ### The next cell should contain the final education table for the purposes of creating the SQL tables.

# %%
df_edu = df_edu.set_index("country_std")

df_edu.head()
# Out:
#                        country  gnp_2005  population_2005  edu_prime_2005  \
# country_std
# Afghanistan        AFGHANISTAN    1010.0       25070798.0             NaN
# Albania                ALBANIA    6060.0        3011487.0             NaN
# Algeria                ALGERIA   10430.0       33288437.0       93.185028
# American Samoa  AMERICAN SAMOA       NaN          59118.0             NaN
# Andorra                ANDORRA       NaN          78867.0             NaN
#
#                 gnp_2010  population_2010  edu_prime_2010  gnp_2015  \
# country_std
# Afghanistan       1590.0       28803167.0             NaN    1940.0
# Albania           9540.0        2913021.0       89.237343   11470.0
# Algeria          12580.0       36117637.0       95.538918   14220.0
# American Samoa       NaN          55637.0             NaN       NaN
# Andorra              NaN          84449.0             NaN       NaN
#
#                 population_2015  edu_prime_2015
# country_std
# Afghanistan          33736494.0             NaN
# Albania               2880703.0      104.468193
# Algeria              39871528.0      105.436417
# American Samoa          55537.0             NaN
# Andorra                 78014.0             NaN

# %% [markdown]
# # Part 5
# * Export everything to postgres

# %%
#set up a postgres connection

from login import username, password

rds_connection_string = f"{username}:{password}@localhost/Project_2"
    
print(rds_connection_string)

engine = create_engine(f'postgresql://{rds_connection_string}')
# Out:
# postgres:postgres@localhost/Project_2

# %%
engine.table_names()
# Out:
# ['edu', 'hdi', 'geo']

# %%
#df_geo (the geography dataframe) to SQL

df_geo.to_sql(name='geo', con=engine, if_exists='append')

#df_hdi (the HDI dataframe) to SQL

df_hdi.to_sql(name='hdi', con=engine, if_exists='append')

#df_edu (the education dataframe) to SQL

df_edu.to_sql(name='edu', con=engine, if_exists='append')
